# %%
cd /content/drive/My Drive/714/code/convdiff
# Out:
# /content/drive/My Drive/714/code/convdiff

# %%
ls
# Out:
# comp_dict.npy                      tmp_figs_12dec_13/
# CONV_DIFF_error_nsims              tmp_figs_12dec_14/
# CONV_DIFF_error_nsims_n1500        tmp_figs_12dec_15/
# diff_file.txt                      tmp_figs_12dec_16/
# diffs_1500.png                     tmp_figs_12dec_17/
# diffs_750_1.png                    tmp_figs_12dec_18/
# diffs_750.png                      tmp_figs_12dec_19/
# diffs_heat_eq.png                  tmp_figs_12dec_2/
# diffs.png                          tmp_figs_12dec_20/
# grid_n1500.png                     tmp_figs_12dec_25/
# grid_n750.png                      tmp_figs_12dec_3/
# grid.png                           tmp_figs_12dec_4/
# grid_sample.png                    tmp_figs_12dec_45/
# grid_sam.png                       tmp_figs_12dec_5/
# HEAT_EQN_epochs                    tmp_figs_12dec_6/
# HEAT_EQN_error_nsims               tmp_figs_12dec_7/
# model_gnode_heat_run_euler.pth     tmp_figs_12dec_8/
# model_gnode_n1500_run_euler.pth    tmp_figs_12dec_9/
# model_gnode_n3000_run_4.pth        tmp_figs_2/
# model_gnode_n3000_run_euler_1.pth  tmp_figs_3/
# model_gnode_n3000_run_euler.pth    tmp_figs_dec12_n1500/
# model_gnode_n750_run_euler.pth     tmp_figs_dec12_n3000/
# paper_exps/                        tmp_figs_dec12_n750/
# pdegs/                             tmp_figs_heat/
# __pycache__/                       tmp_figs_heat_1/
# tb_logs/                           tmp_figs_n1500_1/
# tb_logs_dec12_n1500/               tmp_figs_n1500_14/
# tb_logs_dec12_n3000/               tmp_figs_n1500_25/
# tb_logs_dec12_n750/                tmp_figs_n1500_3/
# tb_logs_heat/                      tmp_figs_n1500_43/
# test1.py                           tmp_figs_n750_1/
# test_exp_noisy_data.py             tmp_figs_n750_15/
# test_exp_nsim_dep.py               tmp_figs_n750_2/
# test.py                            tmp_figs_n750_25/
# tmp_figs/                          tmp_figs_n750_26/
# tmp_figs_1/                        tmp_figs_n750_3/
# tmp_figs_12dec_1/                  tmp_figs_n750_48/
# tmp_figs_12dec_10/                 train_newton.py
# tmp_figs_12dec_11/                 train.py
# tmp_figs_12dec_12/                 utils.py

# %%
# %matplotlib inline

# %%
# !pip install torch_geometric
# Out:
# Collecting torch_geometric
#   Downloading https://files.pythonhosted.org/packages/59/5c/3e95b76321fb14f24cc2ace392075717f645c4632e796ee0db1bc7d17231/torch_geometric-1.6.3.tar.gz (186kB)
#      |████████████████████████████████| 194kB 13.5MB/s
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (from torch_geometric) (1.7.0+cu101)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torch_geometric) (1.18.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from torch_geometric) (4.41.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from torch_geometric) (1.4.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.6/dist-packages (from torch_geometric) (2.5)
# Requirement already satisfied: python-louvain in /usr/local/lib/python3.6/dist-packages (from torch_geometric) (0.14)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.6/dist-packages (from torch_geometric) (0.22.2.post1)
# Requirement already satisfied: numba in /usr/local/lib/python3.6/dist-packages (from torch_geometric) (0.48.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from torch_geometric) (2.23.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from torch_geometric) (1.1.5)
# Collecting rdflib
#   Downloading https://files.pythonhosted.org/packages/d0/6b/6454aa1db753c0f8bc265a5bd5c10b5721a4bb24160fb4faf758cf6be8a1/rdflib-5.0.0-py3-none-any.whl (231kB)
#      |████████████████████████████████| 235kB 31.0MB/s
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from torch_geometric) (2.10.0)
# Requirement already satisfied: googledrivedownloader in /usr/local/lib/python3.6/dist-packages (from torch_geometric) (0.4)
# Collecting ase
#   Downloading https://files.pythonhosted.org/packages/51/78/edadb45c7f26f8fbb99da81feadb561c26bb0393b6c5d1ac200ecdc12d61/ase-3.20.1-py3-none-any.whl (2.2MB)
#      |████████████████████████████████| 2.2MB 52.6MB/s
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.6/dist-packages (from torch_geometric) (2.11.2)
# Requirement already satisfied: dataclasses in /usr/local/lib/python3.6/dist-packages (from torch->torch_geometric) (0.8)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch->torch_geometric) (0.16.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.6/dist-packages (from torch->torch_geometric) (3.7.4.3)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from networkx->torch_geometric) (4.4.2)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->torch_geometric) (0.17.0)
# Requirement already satisfied: llvmlite<0.32.0,>=0.31.0dev0 in /usr/local/lib/python3.6/dist-packages (from numba->torch_geometric) (0.31.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from numba->torch_geometric) (50.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->torch_geometric) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->torch_geometric) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->torch_geometric) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->torch_geometric) (2.10)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas->torch_geometric) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas->torch_geometric) (2018.9)
# Collecting isodate
#   Downloading https://files.pythonhosted.org/packages/9b/9f/b36f7774ff5ea8e428fdcfc4bb332c39ee5b9362ddd3d40d9516a55221b2/isodate-0.6.0-py2.py3-none-any.whl (45kB)
#      |████████████████████████████████| 51kB 9.4MB/s
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.6/dist-packages (from rdflib->torch_geometric) (2.4.7)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from rdflib->torch_geometric) (1.15.0)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from ase->torch_geometric) (3.2.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from jinja2->torch_geometric) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.6/dist-packages (from matplotlib>=2.0.0->ase->torch_geometric) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib>=2.0.0->ase->torch_geometric) (1.3.1)
# Building wheels for collected packages: torch-geometric
#   Building wheel for torch-geometric (setup.py) ... done
#   Created wheel for torch-geometric: filename=torch_geometric-1.6.3-cp36-none-any.whl size=322720 sha256=38179a8476667d86b21e9ac4115b10ae161cee4a3fb13689446bd42c84f60a98
#   Stored in directory: /root/.cache/pip/wheels/6d/47/1e/0af8ce3e21783c3e584c22502011a3367c091694eebc50a971
# Successfully built torch-geometric
# Installing collected packages: isodate, rdflib, ase, torch-geometric
# Successfully installed ase-3.20.1 isodate-0.6.0 rdflib-5.0.0 torch-geometric-1.6.3

# %%
# !pip install torch_sparse
# Out:
# Collecting torch_sparse
#   Using cached https://files.pythonhosted.org/packages/3c/dd/f34dce6512a3922948c3ac0cf50cceb2eeafeedd34a278d502eb77d07dc0/torch_sparse-0.6.8.tar.gz
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from torch_sparse) (1.4.1)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from scipy->torch_sparse) (1.18.5)
# Building wheels for collected packages: torch-sparse
#   Building wheel for torch-sparse (setup.py) ... done
#   Created wheel for torch-sparse: filename=torch_sparse-0.6.8-cp36-cp36m-linux_x86_64.whl size=23315590 sha256=79a1da5cef54abc3df399679c7e255bc6d63a86ce79cd319b90ad2904e6257f3
#   Stored in directory: /root/.cache/pip/wheels/31/d3/94/e2560941994bebe665b1dccc69faf33d33aeee2bca353c9bcc
# Successfully built torch-sparse
# Installing collected packages: torch-sparse
# Successfully installed torch-sparse-0.6.8

# %%
# !pip install torch_scatter
# Out:
# Collecting torch_scatter
#   Using cached https://files.pythonhosted.org/packages/01/45/cd93ed3227248773ba8bc4b3beaa04e8bddb127a793a41bad875369951b3/torch_scatter-2.0.5.tar.gz
# Building wheels for collected packages: torch-scatter
#   Building wheel for torch-scatter (setup.py) ... done
#   Created wheel for torch-scatter: filename=torch_scatter-2.0.5-cp36-cp36m-linux_x86_64.whl size=11774651 sha256=0e224a7b763be03eec78986920a8b2b3f12b59a94d69f4c2c93ec14876092bfe
#   Stored in directory: /root/.cache/pip/wheels/42/59/d3/9866e4fd8e1fe9260740acfe22322c428bc0dc064d3ebc456c
# Successfully built torch-scatter
# Installing collected packages: torch-scatter
# Successfully installed torch-scatter-2.0.5

# %%
# !pip install torchdiffeq==0.1.1
# Out:
# Collecting torchdiffeq==0.1.1
#   Downloading https://files.pythonhosted.org/packages/67/af/377e42c20058f4891dedc1827c1a6b7b16772a452d18097d05c1db06b338/torchdiffeq-0.1.1-py3-none-any.whl
# Requirement already satisfied: torch>=1.3.0 in /usr/local/lib/python3.6/dist-packages (from torchdiffeq==0.1.1) (1.7.0+cu101)
# Requirement already satisfied: dataclasses in /usr/local/lib/python3.6/dist-packages (from torch>=1.3.0->torchdiffeq==0.1.1) (0.8)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.6/dist-packages (from torch>=1.3.0->torchdiffeq==0.1.1) (3.7.4.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torch>=1.3.0->torchdiffeq==0.1.1) (1.18.5)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch>=1.3.0->torchdiffeq==0.1.1) (0.16.0)
# Installing collected packages: torchdiffeq
# Successfully installed torchdiffeq-0.1.1

# %%
#!pip install torch-geometric \
#  torch-sparse==latest+cu101 \
#  torch-scatter==latest+cu101 \
#  torch-cluster==latest+cu101 \
#  -f https://pytorch-geometric.com/whl/torch-1.4.0.html

# %%
#!pip install torch==1.4.0

# %%
#!pip uninstall torchvision
#!pip install torchvision==0.4.0 -f https://download.pytorch.org/whl/torch_stable.html

# %%
# !mkdir tb_logs_dec12_n1500

# %%
# !mkdir tmp_figs_dec12_n1500

# %%
# !python train.py
# Out:
# NUMBER OF RANDOM SIMULATIONS : 24
# Config(d=40, hs_1=60, hs_2=0, method='euler', rtol=1e-07, atol=1e-07, device='cpu', batch_size=None, lr=1e-06, epochs=1000, model_path='./model_gnode_n1500_run_euler.pth', data_path='../data/subs_paper/convdiff_2pi_n1500_t21_train/', tb_log_dir='./tb_logs_dec12_n1500/')
# Num. of params: 19961
# 1 / 24
# 2 / 24
# 3 / 24
# 4 / 24
# 5 / 24
# 6 / 24
# 7 / 24
# 8 / 24
# 9 / 24
# 10 / 24
# 11 / 24
# 12 / 24
# 13 / 24
# 14 / 24
# 15 / 24
# 16 / 24
# 17 / 24
# 18 / 24
# 19 / 24
# 20 / 24
# 21 / 24
# 22 / 24
# 23 / 24
# 24 / 24
# sim_inds = [10 18  7 22  1 16  6 11 20 17  2 13 14 21  4 23  8  0 12 19  3  5 15  9]
# dataset length: 24
# tensor([0.0000, 0.0100, 0.0200, 0.0300, 0.0400, 0.0500, 0.0600, 0.0700, 0.0800,
#         0.0900, 0.1000, 0.1100, 0.1200, 0.1300, 0.1400, 0.1500, 0.1600, 0.1700,
#         0.1800, 0.1900, 0.2000])
# epoch     0 | train loss: 0.035385735333
# epoch    10 | train loss: 0.034945346415
# epoch    20 | train loss: 0.032538879663
# epoch    30 | train loss: 0.023597426713
# epoch    40 | train loss: 0.012513899244
# epoch    50 | train loss: 0.010349935852
# epoch    60 | train loss: 0.009503513575
# epoch    70 | train loss: 0.007458268665
# epoch    80 | train loss: 0.003988814540
# epoch    90 | train loss: 0.002006041119
# epoch   100 | train loss: 0.001466030255
# epoch   110 | train loss: 0.001147715375
# epoch   120 | train loss: 0.000967479311
# epoch   130 | train loss: 0.000847415940
# epoch   140 | train loss: 0.000740294694
# epoch   150 | train loss: 0.000655809650
# epoch   160 | train loss: 0.000576300081
# epoch   170 | train loss: 0.000529060489
# epoch   180 | train loss: 0.000496740045
# epoch   190 | train loss: 0.000468113023
# epoch   200 | train loss: 0.000439319003
# epoch   210 | train loss: 0.000415070157
# epoch   220 | train loss: 0.000391338923
# epoch   230 | train loss: 0.000370022812
# epoch   240 | train loss: 0.000353116367
# epoch   250 | train loss: 0.000342874118
# epoch   260 | train loss: 0.000333308883
# epoch   270 | train loss: 0.000322440668
# epoch   280 | train loss: 0.000314874225
# epoch   290 | train loss: 0.000306626403
# epoch   300 | train loss: 0.000299395528
# epoch   310 | train loss: 0.000293983408
# epoch   320 | train loss: 0.000288140553
# epoch   330 | train loss: 0.000280876178
# epoch   340 | train loss: 0.000274357648
# epoch   350 | train loss: 0.000268743548
# epoch   360 | train loss: 0.000264112721
# epoch   370 | train loss: 0.000259908265
# epoch   380 | train loss: 0.000255222170
# epoch   390 | train loss: 0.000250862038
# epoch   400 | train loss: 0.000246979849
# epoch   410 | train loss: 0.000242869020
# epoch   420 | train loss: 0.000240277281
# epoch   430 | train loss: 0.000237079264
# epoch   440 | train loss: 0.000232747290
# epoch   450 | train loss: 0.000228571414
# epoch   460 | train loss: 0.000225009746
# epoch   470 | train loss: 0.000221238763
# epoch   480 | train loss: 0.000218135334
# epoch   490 | train loss: 0.000215188804
# epoch   500 | train loss: 0.000212957631
# epoch   510 | train loss: 0.000211907827
# epoch   520 | train loss: 0.000210810336
# epoch   530 | train loss: 0.000209117075
# epoch   540 | train loss: 0.000207041376
# epoch   550 | train loss: 0.000204932279
# epoch   560 | train loss: 0.000203338728
# epoch   570 | train loss: 0.000201881150
# epoch   580 | train loss: 0.000200007038
# epoch   590 | train loss: 0.000198223963
# epoch   600 | train loss: 0.000195933957
# epoch   610 | train loss: 0.000194328197
# epoch   620 | train loss: 0.000192778840
# epoch   630 | train loss: 0.000191338710
# epoch   640 | train loss: 0.000189989994
# epoch   650 | train loss: 0.000188924969
# epoch   660 | train loss: 0.000187436424
# epoch   670 | train loss: 0.000186164078
# epoch   680 | train loss: 0.000184997072
# epoch   690 | train loss: 0.000183838580
# epoch   700 | train loss: 0.000182551012
# epoch   710 | train loss: 0.000181193536
# epoch   720 | train loss: 0.000180288524
# epoch   730 | train loss: 0.000179399925
# epoch   740 | train loss: 0.000178524395
# epoch   750 | train loss: 0.000177331051
# epoch   760 | train loss: 0.000176015761
# epoch   770 | train loss: 0.000175131805
# epoch   780 | train loss: 0.000174372777
# epoch   790 | train loss: 0.000173383014
# epoch   800 | train loss: 0.000172461398
# epoch   810 | train loss: 0.000171776643
# epoch   820 | train loss: 0.000171132138
# epoch   830 | train loss: 0.000170244719
# epoch   840 | train loss: 0.000169455176
# epoch   850 | train loss: 0.000168707731
# epoch   860 | train loss: 0.000168000741
# epoch   870 | train loss: 0.000167345701
# epoch   880 | train loss: 0.000166671220
# epoch   890 | train loss: 0.000165940015
# epoch   900 | train loss: 0.000165089441
# epoch   910 | train loss: 0.000164317156
# epoch   920 | train loss: 0.000163644581
# epoch   930 | train loss: 0.000163036253
# epoch   940 | train loss: 0.000162543758
# epoch   950 | train loss: 0.000162184471
# epoch   960 | train loss: 0.000161681935
# epoch   970 | train loss: 0.000161181742
# epoch   980 | train loss: 0.000160845782
# epoch   990 | train loss: 0.000160395124
# epoch   999 | train loss: 0.000159833944
# Plotting...
# (21, 1454, 1)
# (21, 1454, 1)
# torch.Size([21])
# torch.Size([1454, 2])
# Traceback (most recent call last):
#   File "train.py", line 156, in <module>
#     delay=0.0001,
#   File "/content/drive/My Drive/714/code/convdiff/utils.py", line 254, in plot_fields
#     plt.savefig(save_path+"{:s}_{:d}.png".format(key, j))
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py", line 723, in savefig
#     res = fig.savefig(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/figure.py", line 2203, in savefig
#     self.canvas.print_figure(fname, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/backend_bases.py", line 2126, in print_figure
#     **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py", line 535, in print_png
#     with cbook.open_file_cm(filename_or_obj, "wb") as fh:
#   File "/usr/lib/python3.6/contextlib.py", line 81, in __enter__
#     return next(self.gen)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/cbook/__init__.py", line 418, in open_file_cm
#     fh, opened = to_filehandle(path_or_file, mode, True, encoding)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/cbook/__init__.py", line 403, in to_filehandle
#     fh = open(fname, flag, encoding=encoding)
# FileNotFoundError: [Errno 2] No such file or directory: './tmp_figs_12dec_n1500/y_gt_0.png'

# %%
print("Plotting...")
print(y_pd.cpu().detach().numpy().shape)
print(dp.y.numpy().shape)
print(dataset[0].t.shape)
print(dataset[0].pos.shape)
plt.figure(0)
utils.plot_fields(
    t=dataset[0].t,
    coords=dataset[0].pos,
    fields={
        "y_pd": y_pd.cpu().detach().numpy(),
        "y_gt": dp.y.numpy(),
    },
    save_path="./tmp_figs_dec12_n1500/",
    delay=0.0001,
)
plt.show()
# Out:
# Plotting...
# (61, 1454, 1)
# (61, 1454, 1)
# torch.Size([61])
# torch.Size([1454, 2])
# saving./tmp_figs_dec12_n1500/y_gt_0.png
# saving./tmp_figs_dec12_n1500/y_gt_1.png
# saving./tmp_figs_dec12_n1500/y_gt_2.png
# saving./tmp_figs_dec12_n1500/y_gt_3.png
# saving./tmp_figs_dec12_n1500/y_gt_4.png
# saving./tmp_figs_dec12_n1500/y_gt_5.png
# saving./tmp_figs_dec12_n1500/y_gt_6.png
# saving./tmp_figs_dec12_n1500/y_gt_7.png
# saving./tmp_figs_dec12_n1500/y_gt_8.png
# saving./tmp_figs_dec12_n1500/y_gt_9.png
# saving./tmp_figs_dec12_n1500/y_gt_10.png
# saving./tmp_figs_dec12_n1500/y_gt_11.png
# saving./tmp_figs_dec12_n1500/y_gt_12.png
# saving./tmp_figs_dec12_n1500/y_gt_13.png
# saving./tmp_figs_dec12_n1500/y_gt_14.png
# saving./tmp_figs_dec12_n1500/y_gt_15.png
# saving./tmp_figs_dec12_n1500/y_gt_16.png
# saving./tmp_figs_dec12_n1500/y_gt_17.png
# saving./tmp_figs_dec12_n1500/y_gt_18.png
# saving./tmp_figs_dec12_n1500/y_gt_19.png
# saving./tmp_figs_dec12_n1500/y_gt_20.png
# saving./tmp_figs_dec12_n1500/y_gt_21.png
# saving./tmp_figs_dec12_n1500/y_gt_22.png
# saving./tmp_figs_dec12_n1500/y_gt_23.png
# saving./tmp_figs_dec12_n1500/y_gt_24.png
# saving./tmp_figs_dec12_n1500/y_gt_25.png
# saving./tmp_figs_dec12_n1500/y_gt_26.png
# saving./tmp_figs_dec12_n1500/y_gt_27.png
# saving./tmp_figs_dec12_n1500/y_gt_28.png
# saving./tmp_figs_dec12_n1500/y_gt_29.png
# saving./tmp_figs_dec12_n1500/y_gt_30.png
# saving./tmp_figs_dec12_n1500/y_gt_31.png
# saving./tmp_figs_dec12_n1500/y_gt_32.png
# saving./tmp_figs_dec12_n1500/y_gt_33.png
# saving./tmp_figs_dec12_n1500/y_gt_34.png
# saving./tmp_figs_dec12_n1500/y_gt_35.png
# saving./tmp_figs_dec12_n1500/y_gt_36.png
# saving./tmp_figs_dec12_n1500/y_gt_37.png
# saving./tmp_figs_dec12_n1500/y_gt_38.png
# saving./tmp_figs_dec12_n1500/y_gt_39.png
# saving./tmp_figs_dec12_n1500/y_gt_40.png
# saving./tmp_figs_dec12_n1500/y_gt_41.png
# saving./tmp_figs_dec12_n1500/y_gt_42.png
# saving./tmp_figs_dec12_n1500/y_gt_43.png
# saving./tmp_figs_dec12_n1500/y_gt_44.png
# saving./tmp_figs_dec12_n1500/y_gt_45.png
# saving./tmp_figs_dec12_n1500/y_gt_46.png
# saving./tmp_figs_dec12_n1500/y_gt_47.png
# saving./tmp_figs_dec12_n1500/y_gt_48.png
# saving./tmp_figs_dec12_n1500/y_gt_49.png
# saving./tmp_figs_dec12_n1500/y_gt_50.png
# saving./tmp_figs_dec12_n1500/y_gt_51.png
# saving./tmp_figs_dec12_n1500/y_gt_52.png
# saving./tmp_figs_dec12_n1500/y_gt_53.png
# saving./tmp_figs_dec12_n1500/y_gt_54.png
# saving./tmp_figs_dec12_n1500/y_gt_55.png
# saving./tmp_figs_dec12_n1500/y_gt_56.png
# saving./tmp_figs_dec12_n1500/y_gt_57.png
# saving./tmp_figs_dec12_n1500/y_gt_58.png
# saving./tmp_figs_dec12_n1500/y_gt_59.png
# saving./tmp_figs_dec12_n1500/y_gt_60.png

# %%
# !mkdir tb_logs_dec12_n750
# !mkdir tmp_figs_dec12_n750
# !python train.py
# Out:
# mkdir: cannot create directory ‘tb_logs_dec12_n750’: File exists
# mkdir: cannot create directory ‘tmp_figs_dec12_n750’: File exists
# NUMBER OF RANDOM SIMULATIONS : 24
# Config(d=40, hs_1=60, hs_2=0, method='euler', rtol=1e-07, atol=1e-07, device='cpu', batch_size=None, lr=1e-06, epochs=1000, model_path='./model_gnode_n750_run_euler.pth', data_path='../data/subs_paper/convdiff_2pi_n750_t21_train/', tb_log_dir='./tb_logs_dec12_n750/')
# Num. of params: 19961
# 1 / 24
# 2 / 24
# 3 / 24
# 4 / 24
# 5 / 24
# 6 / 24
# 7 / 24
# 8 / 24
# 9 / 24
# 10 / 24
# 11 / 24
# 12 / 24
# 13 / 24
# 14 / 24
# 15 / 24
# 16 / 24
# 17 / 24
# 18 / 24
# 19 / 24
# 20 / 24
# 21 / 24
# 22 / 24
# 23 / 24
# 24 / 24
# sim_inds = [ 4  8  3  0  1 21 10 14  6 11 13  9 18 16 19 12 23  2 15 17  5  7 22 20]
# dataset length: 24
# tensor([0.0000, 0.0100, 0.0200, 0.0300, 0.0400, 0.0500, 0.0600, 0.0700, 0.0800,
#         0.0900, 0.1000, 0.1100, 0.1200, 0.1300, 0.1400, 0.1500, 0.1600, 0.1700,
#         0.1800, 0.1900, 0.2000])
# epoch     0 | train loss: 0.026897009462
# epoch    10 | train loss: 0.026252062991
# epoch    20 | train loss: 0.023158652708
# epoch    30 | train loss: 0.017577195540
# epoch    40 | train loss: 0.011045170948
# epoch    50 | train loss: 0.009815753438
# epoch    60 | train loss: 0.008242244832
# epoch    70 | train loss: 0.004090326373
# epoch    80 | train loss: 0.002635566751
# epoch    90 | train loss: 0.001979270484
# epoch   100 | train loss: 0.001718252897
# epoch   110 | train loss: 0.001508473419
# epoch   120 | train loss: 0.001330378931
# epoch   130 | train loss: 0.001203428954
# epoch   140 | train loss: 0.001104058349
# epoch   150 | train loss: 0.001009567291
# epoch   160 | train loss: 0.000948118570
# epoch   170 | train loss: 0.000901684514
# epoch   180 | train loss: 0.000869582931
# epoch   190 | train loss: 0.000832375896
# epoch   200 | train loss: 0.000797018583
# epoch   210 | train loss: 0.000765965728
# epoch   220 | train loss: 0.000741497963
# epoch   230 | train loss: 0.000714292168
# epoch   240 | train loss: 0.000694155868
# epoch   250 | train loss: 0.000674051349
# epoch   260 | train loss: 0.000653704163
# epoch   270 | train loss: 0.000630612369
# epoch   280 | train loss: 0.000610101153
# epoch   290 | train loss: 0.000591950782
# epoch   300 | train loss: 0.000574970152
# epoch   310 | train loss: 0.000558113155
# epoch   320 | train loss: 0.000541459071
# epoch   330 | train loss: 0.000527049531
# epoch   340 | train loss: 0.000512825791
# epoch   350 | train loss: 0.000502240669
# epoch   360 | train loss: 0.000492509629
# epoch   370 | train loss: 0.000483151816
# epoch   380 | train loss: 0.000473795517
# epoch   390 | train loss: 0.000464476820
# epoch   400 | train loss: 0.000456520182
# epoch   410 | train loss: 0.000450583524
# epoch   420 | train loss: 0.000444930512
# epoch   430 | train loss: 0.000439852854
# epoch   440 | train loss: 0.000434167159
# epoch   450 | train loss: 0.000429773354
# epoch   460 | train loss: 0.000425421749
# epoch   470 | train loss: 0.000420755387
# epoch   480 | train loss: 0.000416799303
# epoch   490 | train loss: 0.000413315662
# epoch   500 | train loss: 0.000409327535
# epoch   510 | train loss: 0.000405684259
# epoch   520 | train loss: 0.000402502978
# epoch   530 | train loss: 0.000399340846
# epoch   540 | train loss: 0.000396508956
# epoch   550 | train loss: 0.000393642433
# epoch   560 | train loss: 0.000390608417
# epoch   570 | train loss: 0.000387687993
# epoch   580 | train loss: 0.000384712912
# epoch   590 | train loss: 0.000382013764
# epoch   600 | train loss: 0.000379219244
# epoch   610 | train loss: 0.000376393291
# epoch   620 | train loss: 0.000373512448
# epoch   630 | train loss: 0.000370972557
# epoch   640 | train loss: 0.000368720735
# epoch   650 | train loss: 0.000366146705
# epoch   660 | train loss: 0.000363972445
# epoch   670 | train loss: 0.000362253370
# epoch   680 | train loss: 0.000359962694
# epoch   690 | train loss: 0.000358015823
# epoch   700 | train loss: 0.000355885160
# epoch   710 | train loss: 0.000354248245
# epoch   720 | train loss: 0.000352564355
# epoch   730 | train loss: 0.000350896618
# epoch   740 | train loss: 0.000349283975
# epoch   750 | train loss: 0.000347663503
# epoch   760 | train loss: 0.000345804321
# epoch   770 | train loss: 0.000344228960
# epoch   780 | train loss: 0.000342763640
# epoch   790 | train loss: 0.000341488601
# epoch   800 | train loss: 0.000340088067
# epoch   810 | train loss: 0.000338861108
# epoch   820 | train loss: 0.000337540725
# epoch   830 | train loss: 0.000336285011
# epoch   840 | train loss: 0.000334919197
# epoch   850 | train loss: 0.000333790987
# epoch   860 | train loss: 0.000332456810
# epoch   870 | train loss: 0.000331418269
# epoch   880 | train loss: 0.000330300943
# epoch   890 | train loss: 0.000329064671
# epoch   900 | train loss: 0.000327884074
# epoch   910 | train loss: 0.000326726557
# epoch   920 | train loss: 0.000325709290
# epoch   930 | train loss: 0.000324559602
# epoch   940 | train loss: 0.000323365617
# epoch   950 | train loss: 0.000322351640
# epoch   960 | train loss: 0.000321380037
# epoch   970 | train loss: 0.000320241437
# epoch   980 | train loss: 0.000319346465
# epoch   990 | train loss: 0.000318365142
# epoch   999 | train loss: 0.000317558442
# Plotting...
# (21, 725, 1)
# (21, 725, 1)
# torch.Size([21])
# torch.Size([725, 2])
# Traceback (most recent call last):
#   File "train.py", line 156, in <module>
#     delay=0.0001,
#   File "/content/drive/My Drive/714/code/convdiff/utils.py", line 254, in plot_fields
#     plt.savefig(save_path+"{:s}_{:d}.png".format(key, j))
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py", line 723, in savefig
#     res = fig.savefig(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/figure.py", line 2203, in savefig
#     self.canvas.print_figure(fname, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/backend_bases.py", line 2126, in print_figure
#     **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py", line 535, in print_png
#     with cbook.open_file_cm(filename_or_obj, "wb") as fh:
#   File "/usr/lib/python3.6/contextlib.py", line 81, in __enter__
#     return next(self.gen)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/cbook/__init__.py", line 418, in open_file_cm
#     fh, opened = to_filehandle(path_or_file, mode, True, encoding)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/cbook/__init__.py", line 403, in to_filehandle
#     fh = open(fname, flag, encoding=encoding)
# FileNotFoundError: [Errno 2] No such file or directory: './tmp_figs_12dec_n750/y_gt_0.png'

# %%
# !mkdir tb_logs_dec12_n750
# !mkdir tmp_figs_dec12_n750
# !python train.py
# Out:
# NUMBER OF RANDOM SIMULATIONS : 24
# Config(d=40, hs_1=60, hs_2=0, method='euler', rtol=1e-07, atol=1e-07, device='cpu', batch_size=None, lr=1e-06, epochs=1000, model_path='./model_gnode_n3000_run_euler_1.pth', data_path='../data/subs_paper/convdiff_2pi_n3000_t21_train/', tb_log_dir='./tb_logs_dec12_n3000/')
# Num. of params: 19961
# 1 / 24
# 2 / 24
# 3 / 24
# 4 / 24
# 5 / 24
# 6 / 24
# 7 / 24
# 8 / 24
# 9 / 24
# 10 / 24
# 11 / 24
# 12 / 24
# 13 / 24
# 14 / 24
# 15 / 24
# 16 / 24
# 17 / 24
# 18 / 24
# 19 / 24
# 20 / 24
# 21 / 24
# 22 / 24
# 23 / 24
# 24 / 24
# sim_inds = [17 19 18  5 16 10 12 20 14  2 22 13  9 11  3  7  6 23  0  8 21  4  1 15]
# dataset length: 24
# tensor([0.0000, 0.0100, 0.0200, 0.0300, 0.0400, 0.0500, 0.0600, 0.0700, 0.0800,
#         0.0900, 0.1000, 0.1100, 0.1200, 0.1300, 0.1400, 0.1500, 0.1600, 0.1700,
#         0.1800, 0.1900, 0.2000])
# epoch     0 | train loss: 0.036522228271
# epoch    10 | train loss: 0.035698581487
# epoch    20 | train loss: 0.031271558255
# epoch    30 | train loss: 0.022765871137
# epoch    40 | train loss: 0.013340502977
# epoch    50 | train loss: 0.010866570286
# epoch    60 | train loss: 0.010279582813
# epoch    70 | train loss: 0.009395637549
# epoch    80 | train loss: 0.005583272316
# epoch    90 | train loss: 0.002624010900
# epoch   100 | train loss: 0.001964893192
# epoch   110 | train loss: 0.001965108793
# epoch   120 | train loss: 0.002501502400
# epoch   130 | train loss: 0.003294819733
# epoch   140 | train loss: 0.005145731382
# epoch   150 | train loss: 0.006085630506
# epoch   160 | train loss: 0.007382554933
# epoch   170 | train loss: 0.009972928092
# epoch   180 | train loss: 0.012657532468
# epoch   190 | train loss: 0.013694981113
# epoch   200 | train loss: 0.015400689095
# epoch   210 | train loss: 0.019562350586
# epoch   220 | train loss: 0.020079351962
# epoch   230 | train loss: 0.019940849394
# epoch   240 | train loss: 0.020055150613
# epoch   250 | train loss: 0.020193181932
# epoch   260 | train loss: 0.020666563883
# epoch   270 | train loss: 0.021118212491
# epoch   280 | train loss: 0.021366162226
# epoch   290 | train loss: 0.021456714720
# epoch   300 | train loss: 0.021676393226
# epoch   310 | train loss: 0.021999211982

# %%
# !python -c "import torch; print(torch.__version__)"
# Out:
# 1.6.0

# %%
# !python test.py

# %%
# !ls
# Out:
# comp_dict.npy		     __pycache__	     tmp_figs
# diffs.png		     tb_logs		     train_newton.py
# model_gnode_n3000_run_4.pth  test_exp_noisy_data.py  train.py
# paper_exps		     test_exp_nsim_dep.py    utils.py
# pdegs			     test.py

# %% [markdown]
# Modified Test file

# %%
# !python test.py

# %%
import torch
import torch.nn as nn

from torch_geometric.data import DataLoader

import numpy as np

import matplotlib.pyplot as plt

from pdegs.dynamics import DynamicsFunction
from pdegs.integrators import ODEAdjointIntegrator
from pdegs.models import Model3, MPNNDiff

from collections import namedtuple

import utils


# can be replaced by argparse
Config = namedtuple(
    "Config", 
    [
        "d", "hs_1", "hs_2", "method", "rtol", 
        "atol", "device", "model_path", "data_path"
    ]
)

args = Config(
    d=40,
    hs_1=60,
    hs_2=0,
    method="euler",
    rtol=1.0e-7,
    atol=1.0e-7,
    device="cuda",
    model_path="./model_gnode_n750_run_euler.pth",
    data_path="../data/subs_paper/convdiff_2pi_n750_t21_test/",
)

device = torch.device(args.device)

# Create model
# Model3 
# L1_msg_net = nn.Sequential(nn.Linear(2, args.hs_1), nn.Tanh(), nn.Linear(args.hs_1, args.d))
# L1_aggr_net = nn.Sequential(nn.Linear(args.d, args.hs_1), nn.Tanh(), nn.Linear(args.hs_1, args.d))
# L2_msg_net = nn.Sequential(nn.Linear(4+args.d, args.hs_2), nn.Tanh(), nn.Linear(args.hs_2, args.d))
# L2_aggr_net = nn.Sequential(nn.Linear(args.d, args.hs_2), nn.Tanh(), nn.Linear(args.hs_2, 1))
# model = Model3(L1_msg_net, L1_aggr_net, L2_msg_net, L2_aggr_net)

# MPNN
msg_net = nn.Sequential(
    nn.Linear(4, args.hs_1), nn.Tanh(), 
    nn.Linear(args.hs_1, args.hs_1), nn.Tanh(), 
    nn.Linear(args.hs_1, args.hs_1), nn.Tanh(), 
    nn.Linear(args.hs_1, args.d)
)
aggr_net = nn.Sequential(
    nn.Linear(args.d+1, args.hs_1), nn.Tanh(), 
    nn.Linear(args.hs_1, args.hs_1), nn.Tanh(), 
    nn.Linear(args.hs_1, args.hs_1), nn.Tanh(), 
    nn.Linear(args.hs_1, 1)
)
model = MPNNDiff(msg_net, aggr_net)

F = DynamicsFunction(model).to(device)
F.load_state_dict(torch.load(args.model_path, map_location=device))

# Create integrator
adj_integr = ODEAdjointIntegrator()

# Prepare data
data = utils.read_pickle(['t', 'x', 'u'], args.data_path)
print(data['t'].shape)

dataset = utils.generate_torchgeom_dataset(data)
loader = DataLoader(dataset, batch_size=1, shuffle=False)

# Loss
loss_fn = nn.MSELoss()

# Testing
diffs_over_time = []
losses = torch.zeros(len(loader))

inds_of_sims_to_show = set([])
# Out:
# (50, 61)
# 1 / 50
# 2 / 50
# 3 / 50
# 4 / 50
# 5 / 50
# 6 / 50
# 7 / 50
# 8 / 50
# 9 / 50
# 10 / 50
# 11 / 50
# 12 / 50
# 13 / 50
# 14 / 50
# 15 / 50
# 16 / 50
# 17 / 50
# 18 / 50
# 19 / 50
# 20 / 50
# 21 / 50
# 22 / 50
# 23 / 50
# 24 / 50
# 25 / 50
# 26 / 50
# 27 / 50
# 28 / 50
# 29 / 50
# 30 / 50
# 31 / 50
# 32 / 50
# 33 / 50
# 34 / 50
# 35 / 50
# 36 / 50
# 37 / 50
# 38 / 50
# 39 / 50
# 40 / 50
# 41 / 50
# 42 / 50
# 43 / 50
# 44 / 50
# 45 / 50
# 46 / 50
# 47 / 50
# 48 / 50
# 49 / 50
# 50 / 50

# %%
args = Config(
    d=40,
    hs_1=60,
    hs_2=0,
    method="euler",
    rtol=1.0e-7,
    atol=1.0e-7,
    device="cuda",
    model_path="./model_gnode_n3000_run_4.pth",
    data_path="../data/subs_paper/convdiff_2pi_n3000_t21_test/",
)

# %%
args = Config(
    d=40,
    hs_1=60,
    hs_2=0,
    method="euler",
    rtol=1.0e-7,
    atol=1.0e-7,
    device="cuda",
    model_path="./model_gnode_n1500_run_euler.pth",
    data_path="../data/subs_paper/convdiff_2pi_n1500_t21_test/",
)

# %%
args = Config(
    d=40,
    hs_1=60,
    hs_2=0,
    method="euler",
    rtol=1.0e-7,
    atol=1.0e-7,
    device="cuda",
    model_path="./model_gnode_n750_run_euler.pth",
    data_path="../data/subs_paper/convdiff_2pi_n750_t21_test/",
)

# %%
inds_of_sims_to_show
# Out:
# set()

# %%
# !ls
# Out:
# comp_dict.npy			 tb_logs		 tmp_figs_12dec_2
# diffs.png			 test1.py		 tmp_figs_12dec_45
# grid.png			 test_exp_noisy_data.py  tmp_figs_2
# model_gnode_n3000_run_4.pth	 test_exp_nsim_dep.py	 tmp_figs_3
# model_gnode_n3000_run_euler.pth  test.py		 train_newton.py
# paper_exps			 tmp_figs		 train.py
# pdegs				 tmp_figs_1		 utils.py
# __pycache__			 tmp_figs_12dec_1

# %% [markdown]
# PLOT EVOLUTION HEATMAP

# %%
#!mkdir tmp_figs_n750_48
inds_of_sims_to_show = set([48])
diffs_over_time = []

# %%
for i, dp in enumerate(loader):
    params_dict = {"edge_index": dp.edge_index.to(device), "pos": dp.pos.to(device)}
    F.update_params(params_dict)

    y0 = dp.x.to(device)
    t = dp.t.to(device)
    y_pd = adj_integr.integrate(
        F, y0, t, method=args.method, rtol=args.rtol, atol=args.atol)
    
    y_gt = dp.y.to(device)

    loss = loss_fn(y_pd, y_gt)

    losses[i] = loss.item()

    u = y_gt.cpu().detach().numpy()
    u_pd = y_pd.cpu().detach().numpy()
    u_mean = u.mean(axis=1).reshape(-1)

    # diffs = [((u[i] - u_pd[i])**2).mean() for i in range(len(u))]
    
    eps = 1.0e-6
    diffs = [np.linalg.norm(u[i].reshape(-1) - u_pd[i].reshape(-1)) / (np.linalg.norm(u[i].reshape(-1)) + eps) for i in range(len(u))]
    
    diffs_over_time.append(diffs)

    print("test case {:>5d} | test loss: {:>7.12f}".format(i, losses[i]))
    print("inds_of_sims_to_show" + str(inds_of_sims_to_show))
    if i in inds_of_sims_to_show:
        print("Plotting...")
        utils.plot_grid(dataset[i].pos.cpu().detach().numpy())
        plt.figure(0)
        utils.plot_fields(
            t=dataset[i].t,
            coords=dataset[i].pos,
            fields={
                "y_pd": y_pd.cpu().detach().numpy(),
                "y_gt": dp.y.numpy(),
            },
            save_path="./tmp_figs_n750_48/",
            delay=0.0001,
        )
        plt.show()

    # if i == 2:  # 3 for grids, 2 for time points
    #     break
# Out:
# test case     0 | test loss: 0.000632031122
# inds_of_sims_to_show{48}
# test case     1 | test loss: 0.000921646366
# inds_of_sims_to_show{48}
# test case     2 | test loss: 0.001081077382
# inds_of_sims_to_show{48}
# test case     3 | test loss: 0.001854378730
# inds_of_sims_to_show{48}
# test case     4 | test loss: 0.001843510661
# inds_of_sims_to_show{48}
# test case     5 | test loss: 0.000995843788
# inds_of_sims_to_show{48}
# test case     6 | test loss: 0.000781270850
# inds_of_sims_to_show{48}
# test case     7 | test loss: 0.000890819996
# inds_of_sims_to_show{48}
# test case     8 | test loss: 0.000801232003
# inds_of_sims_to_show{48}
# test case     9 | test loss: 0.000664066465
# inds_of_sims_to_show{48}
# test case    10 | test loss: 0.001460900181
# inds_of_sims_to_show{48}
# test case    11 | test loss: 0.001047989354
# inds_of_sims_to_show{48}
# test case    12 | test loss: 0.000972599839
# inds_of_sims_to_show{48}
# test case    13 | test loss: 0.000772808213
# inds_of_sims_to_show{48}
# test case    14 | test loss: 0.001046708436
# inds_of_sims_to_show{48}
# test case    15 | test loss: 0.000663194689
# inds_of_sims_to_show{48}
# test case    16 | test loss: 0.000541394402
# inds_of_sims_to_show{48}
# test case    17 | test loss: 0.001052049105
# inds_of_sims_to_show{48}
# test case    18 | test loss: 0.001039744471
# inds_of_sims_to_show{48}
# test case    19 | test loss: 0.000879008730
# inds_of_sims_to_show{48}
# test case    20 | test loss: 0.000653704454
# inds_of_sims_to_show{48}
# test case    21 | test loss: 0.000713265152
# inds_of_sims_to_show{48}
# test case    22 | test loss: 0.000677027041
# inds_of_sims_to_show{48}
# test case    23 | test loss: 0.000581392960
# inds_of_sims_to_show{48}
# test case    24 | test loss: 0.000709566521
# inds_of_sims_to_show{48}
# test case    25 | test loss: 0.000619923288
# inds_of_sims_to_show{48}
# test case    26 | test loss: 0.000535676780
# inds_of_sims_to_show{48}
# test case    27 | test loss: 0.000943050778
# inds_of_sims_to_show{48}
# test case    28 | test loss: 0.001042216900
# inds_of_sims_to_show{48}
# test case    29 | test loss: 0.000983880134
# inds_of_sims_to_show{48}
# test case    30 | test loss: 0.000907992478
# inds_of_sims_to_show{48}
# test case    31 | test loss: 0.001225958578
# inds_of_sims_to_show{48}
# test case    32 | test loss: 0.000657319499
# inds_of_sims_to_show{48}
# test case    33 | test loss: 0.000899863720
# inds_of_sims_to_show{48}
# test case    34 | test loss: 0.001085324562
# inds_of_sims_to_show{48}
# test case    35 | test loss: 0.000914526056
# inds_of_sims_to_show{48}
# test case    36 | test loss: 0.000929261209
# inds_of_sims_to_show{48}
# test case    37 | test loss: 0.001129531767
# inds_of_sims_to_show{48}
# test case    38 | test loss: 0.000704544014
# inds_of_sims_to_show{48}
# test case    39 | test loss: 0.000702128280
# inds_of_sims_to_show{48}
# test case    40 | test loss: 0.000842660433
# inds_of_sims_to_show{48}
# test case    41 | test loss: 0.000656113145
# inds_of_sims_to_show{48}
# test case    42 | test loss: 0.000641330495
# inds_of_sims_to_show{48}
# test case    43 | test loss: 0.000584149733
# inds_of_sims_to_show{48}
# test case    44 | test loss: 0.001256418182
# inds_of_sims_to_show{48}
# test case    45 | test loss: 0.000578138453
# inds_of_sims_to_show{48}
# test case    46 | test loss: 0.000639090722
# inds_of_sims_to_show{48}
# test case    47 | test loss: 0.000841840054
# inds_of_sims_to_show{48}
# test case    48 | test loss: 0.001479669823
# inds_of_sims_to_show{48}
# Plotting...
# saving./tmp_figs_n750_48/y_gt_0.png
# saving./tmp_figs_n750_48/y_gt_1.png
# saving./tmp_figs_n750_48/y_gt_2.png
# saving./tmp_figs_n750_48/y_gt_3.png
# saving./tmp_figs_n750_48/y_gt_4.png
# saving./tmp_figs_n750_48/y_gt_5.png
# saving./tmp_figs_n750_48/y_gt_6.png
# saving./tmp_figs_n750_48/y_gt_7.png
# saving./tmp_figs_n750_48/y_gt_8.png
# saving./tmp_figs_n750_48/y_gt_9.png
# saving./tmp_figs_n750_48/y_gt_10.png
# saving./tmp_figs_n750_48/y_gt_11.png
# saving./tmp_figs_n750_48/y_gt_12.png
# saving./tmp_figs_n750_48/y_gt_13.png
# saving./tmp_figs_n750_48/y_gt_14.png
# saving./tmp_figs_n750_48/y_gt_15.png
# saving./tmp_figs_n750_48/y_gt_16.png
# saving./tmp_figs_n750_48/y_gt_17.png
# saving./tmp_figs_n750_48/y_gt_18.png
# saving./tmp_figs_n750_48/y_gt_19.png
# saving./tmp_figs_n750_48/y_gt_20.png
# saving./tmp_figs_n750_48/y_gt_21.png
# saving./tmp_figs_n750_48/y_gt_22.png
# saving./tmp_figs_n750_48/y_gt_23.png
# saving./tmp_figs_n750_48/y_gt_24.png
# saving./tmp_figs_n750_48/y_gt_25.png
# saving./tmp_figs_n750_48/y_gt_26.png
# saving./tmp_figs_n750_48/y_gt_27.png
# saving./tmp_figs_n750_48/y_gt_28.png
# saving./tmp_figs_n750_48/y_gt_29.png
# saving./tmp_figs_n750_48/y_gt_30.png
# saving./tmp_figs_n750_48/y_gt_31.png
# saving./tmp_figs_n750_48/y_gt_32.png
# saving./tmp_figs_n750_48/y_gt_33.png
# saving./tmp_figs_n750_48/y_gt_34.png
# saving./tmp_figs_n750_48/y_gt_35.png
# saving./tmp_figs_n750_48/y_gt_36.png
# saving./tmp_figs_n750_48/y_gt_37.png
# saving./tmp_figs_n750_48/y_gt_38.png
# saving./tmp_figs_n750_48/y_gt_39.png
# saving./tmp_figs_n750_48/y_gt_40.png
# saving./tmp_figs_n750_48/y_gt_41.png
# saving./tmp_figs_n750_48/y_gt_42.png
# saving./tmp_figs_n750_48/y_gt_43.png
# saving./tmp_figs_n750_48/y_gt_44.png
# saving./tmp_figs_n750_48/y_gt_45.png
# saving./tmp_figs_n750_48/y_gt_46.png
# saving./tmp_figs_n750_48/y_gt_47.png
# saving./tmp_figs_n750_48/y_gt_48.png
# saving./tmp_figs_n750_48/y_gt_49.png
# saving./tmp_figs_n750_48/y_gt_50.png
# saving./tmp_figs_n750_48/y_gt_51.png
# saving./tmp_figs_n750_48/y_gt_52.png
# saving./tmp_figs_n750_48/y_gt_53.png
# saving./tmp_figs_n750_48/y_gt_54.png
# saving./tmp_figs_n750_48/y_gt_55.png
# saving./tmp_figs_n750_48/y_gt_56.png
# saving./tmp_figs_n750_48/y_gt_57.png
# saving./tmp_figs_n750_48/y_gt_58.png
# saving./tmp_figs_n750_48/y_gt_59.png
# saving./tmp_figs_n750_48/y_gt_60.png
# test case    49 | test loss: 0.000705988728
# inds_of_sims_to_show{48}

# %%
# comp_dict = np.load("./paper_exps/comp_dict_paper_diff_step_size.npy", allow_pickle='TRUE').item()
comp_dict = {}

comp_dict_upd = {
    # 'coords_true': dataset[2].pos.numpy(), 
    # 'fields_true': dataset[2].y.numpy(),
    'coords_t_11': dataset[2].pos.numpy(),
    'fields_t_11': y_pd.cpu().detach().numpy(),
    
}
comp_dict.update(comp_dict_upd)
np.save("./paper_exps/comp_dict_paper_diff_step_size.npy", comp_dict)
print(comp_dict.keys())

print("Plotting diffs...")
plt.figure(0)
t = dataset[0].t.numpy()

for diff in diffs_over_time:
    #plt.semilogy(t, diff, alpha=0.5)
    plt.plot(t, diff, alpha=0.5)
plt.vlines(0.2, 0, 0.00002, color='gray')

plt.ylabel("MSE")
plt.xlabel("t (sec)")

plt.savefig("diffs_3000_1.png")

diffs_over_time = np.array(diffs_over_time)
print("diffs_over_time.shape", diffs_over_time.shape)
print("diffs_over_time.mean", diffs_over_time.mean())

# save_to = "./plot_data/time_11tpts.npy"
# np.save(save_to, diffs_over_time)
# Out:
# dict_keys(['coords_t_11', 'fields_t_11'])
# Plotting diffs...
# diffs_over_time.shape (50, 61)
# diffs_over_time.mean 0.0575424449452833

# %%
np.savetxt('diff_file_3000.txt', diffs_over_time)

# %%
import seaborn as sns

# %% [markdown]
# **HEAT EQUATION**

# %%
# !ls
# Out:
# drive  sample_data

# %%
cd /content/drive/MyDrive/714/code/data
# Out:
# /content/drive/MyDrive/714/code/data

# %%
# !ls
# Out:
# downsample.py  full  periodic_downsample.py  subs  subs_paper

# %%
# !python downsample.py
# Out:
# Reading from ./full/heat_unit_square_test/
# tcmalloc: large alloc 1260421120 bytes == 0x2c64000 @  0x7fc98727f1e7 0x59211c 0x4cddd0 0x5669e2 0x5a4cd1 0x4ddd76 0x5eae15 0x4debf7 0x5ebace 0x50a25a 0x50beb4 0x507be4 0x509900 0x50a2fd 0x50cc96 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x50ad03 0x634e72 0x634f27 0x6386df 0x639281 0x4b0dc0 0x7fc986e7cbf7 0x5b259a
# tcmalloc: large alloc 1260421120 bytes == 0x4de6c000 @  0x7fc98727f1e7 0x59211c 0x5eadd6 0x4debf7 0x5ebace 0x50a25a 0x50beb4 0x507be4 0x509900 0x50a2fd 0x50cc96 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x50ad03 0x634e72 0x634f27 0x6386df 0x639281 0x4b0dc0 0x7fc986e7cbf7 0x5b259a
# Data shape
# t (50, 3001)
# x (50, 1050, 2)
# u (50, 3001, 1050, 1)
# New data shape
# t (50, 61)
# x (50, 1050, 2)
# u (50, 61, 1050, 1)
# Saved to ./subs/heat_unit_square_test_1_0p/

# %% [markdown]
# **Training Heat equation**

# %%
# !mkdir tmp_figs_heat
# !mkdir tb_logs_heat

# %%
import numpy as np
from collections import namedtuple

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.tensorboard import SummaryWriter

from torch_geometric.data import DataLoader

import matplotlib.pyplot as plt

from pdegs.dynamics import DynamicsFunction
from pdegs.integrators import ODEAdjointIntegrator
from pdegs.models import MPNNDiff, Model3

import utils


# Can be replaced by argparse
Config = namedtuple(
    "Config", 
    [
        "d", "hs_1", "hs_2", "method", "rtol", 
        "atol", "device", "batch_size", "lr", 
        "epochs", "model_path", "data_path",
        "tb_log_dir",
    ]
)

args = Config(
    d=40,
    hs_1=60,
    hs_2=0,
    method="euler",  #euler
    rtol=1.0e-7,
    atol=1.0e-7,
    device="cpu", #CHANGE cuda
    batch_size=None,  # Use None for full batch
    lr=0.000001,
    epochs=1000,
    model_path="./model_gnode_heat_run_euler.pth",
    data_path="../data/subs/heat_unit_square_test_1_0p/",
    tb_log_dir="./tb_logs_heat/",
)

n_s = 24

print("NUMBER OF RANDOM SIMULATIONS :", n_s)

print(args)
device = torch.device(args.device)
writer = SummaryWriter(log_dir=args.tb_log_dir)

# Create model
msg_net = nn.Sequential(
    nn.Linear(4, args.hs_1), nn.Tanh(), 
    nn.Linear(args.hs_1, args.hs_1), nn.Tanh(), 
    nn.Linear(args.hs_1, args.hs_1), nn.Tanh(), 
    nn.Linear(args.hs_1, args.d)
)
aggr_net = nn.Sequential(
    nn.Linear(args.d+1, args.hs_1), nn.Tanh(), 
    nn.Linear(args.hs_1, args.hs_1), nn.Tanh(), 
    nn.Linear(args.hs_1, args.hs_1), nn.Tanh(), 
    nn.Linear(args.hs_1, 1)
)
model = MPNNDiff(msg_net, aggr_net)

model.apply(utils.weights_init)
print("Num. of params: {:d}".format(utils.get_parameters_count(model)))

F = DynamicsFunction(model).to(device)

# Create integrator
adj_integr = ODEAdjointIntegrator()

# Prepare data
data = utils.read_pickle(['t', 'x', 'u'], args.data_path)
dataset = utils.generate_torchgeom_dataset(data, sig=0.0)

# #########
sim_inds = np.random.choice(len(dataset), n_s, replace=False)
print(f'sim_inds = {sim_inds}')
dataset = [ds for i, ds in enumerate(dataset) if i in sim_inds]
print(f'dataset length: {len(dataset)}')
# #########

if args.batch_size is None:
    batch_size = len(dataset)

loader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

# Optimizer, loss
optimizer = optim.Rprop(F.parameters(), lr=args.lr)
loss_fn = nn.MSELoss()

# Training
ts = dataset[0].t.shape[0]  # assumes the same time grid for all sim-s.
print(dataset[0].t)
for epoch in range(args.epochs):
    losses = torch.zeros(len(loader))
    
    for i, dp in enumerate(loader):
        optimizer.zero_grad()

        params_dict = {"edge_index": dp.edge_index.to(device), "pos": dp.pos.to(device)}
        F.update_params(params_dict)

        y0 = dp.x.to(device)
        t = dp.t[0:ts].to(device)
        y_pd = adj_integr.integrate(
            F, y0, t, method=args.method, rtol=args.rtol, atol=args.atol)
        
        sims = []
        for j in range(batch_size):
            sims.append(dp.y[j*ts:(j+1)*ts])  # TODO: just transpose 0, 1 ?
        y_gt = torch.cat(sims, dim=1)

        loss = loss_fn(y_pd, y_gt.to(device))
        loss.backward()
        optimizer.step()

        losses[i] = loss.item()
        
    writer.add_scalar("train_loss/"+str(args), losses.mean(), epoch)
    
    if epoch % 10 == 0 or epoch == args.epochs - 1:
        print("epoch {:>5d} | train loss: {:>7.12f}".format(epoch, losses.mean()))
        torch.save(F.state_dict(), args.model_path)
    if losses.mean() <= 0.0001:
        break

dp = dataset[0]
params_dict = {"edge_index": dp.edge_index.to(device), "pos": dp.pos.to(device)}
F.update_params(params_dict)
y0 = dp.x.to(device)
t = dp.t[0:ts].to(device)
y_pd = adj_integr.integrate(
    F, y0, t, method=args.method, rtol=args.rtol, atol=args.atol)

print("Plotting...")
print(y_pd.cpu().detach().numpy().shape)
print(dp.y.numpy().shape)
print(dataset[0].t.shape)
print(dataset[0].pos.shape)
plt.figure(0)
utils.plot_fields(
    t=dataset[0].t,
    coords=dataset[0].pos,
    fields={
        "y_pd": y_pd.cpu().detach().numpy(),
        "y_gt": dp.y.numpy(),
    },
    save_path="./tmp_figs_heat/",
    delay=0.0001,
)
plt.show()
# Out:
# NUMBER OF RANDOM SIMULATIONS : 24
# Config(d=40, hs_1=60, hs_2=0, method='euler', rtol=1e-07, atol=1e-07, device='cpu', batch_size=None, lr=1e-06, epochs=1000, model_path='./model_gnode_heat_run_euler.pth', data_path='../data/subs/heat_unit_square_test_1_0p/', tb_log_dir='./tb_logs_heat/')
# Num. of params: 19961
# 1 / 50
# 2 / 50
# 3 / 50
# 4 / 50
# 5 / 50
# 6 / 50
# 7 / 50
# 8 / 50
# 9 / 50
# 10 / 50
# 11 / 50
# 12 / 50
# 13 / 50
# 14 / 50
# 15 / 50
# 16 / 50
# 17 / 50
# 18 / 50
# 19 / 50
# 20 / 50
# 21 / 50
# 22 / 50
# 23 / 50
# 24 / 50
# 25 / 50
# 26 / 50
# 27 / 50
# 28 / 50
# 29 / 50
# 30 / 50
# 31 / 50
# 32 / 50
# 33 / 50
# 34 / 50
# 35 / 50
# 36 / 50
# 37 / 50
# 38 / 50
# 39 / 50
# 40 / 50
# 41 / 50
# 42 / 50
# 43 / 50
# 44 / 50
# 45 / 50
# 46 / 50
# 47 / 50
# 48 / 50
# 49 / 50
# 50 / 50
# sim_inds = [ 3  5 22  1 37 25 12  0 41 39 43 44 38 32 18 35 48 27 10 30  7 19 47 49]
# dataset length: 24
# tensor([0.0000, 0.0050, 0.0100, 0.0150, 0.0200, 0.0250, 0.0300, 0.0350, 0.0400,
#         0.0450, 0.0500, 0.0550, 0.0600, 0.0650, 0.0700, 0.0750, 0.0800, 0.0850,
#         0.0900, 0.0950, 0.1000, 0.1050, 0.1100, 0.1150, 0.1200, 0.1250, 0.1300,
#         0.1350, 0.1400, 0.1450, 0.1500, 0.1550, 0.1600, 0.1650, 0.1700, 0.1750,
#         0.1800, 0.1850, 0.1900, 0.1950, 0.2000, 0.2050, 0.2100, 0.2150, 0.2200,
#         0.2250, 0.2300, 0.2350, 0.2400, 0.2450, 0.2500, 0.2550, 0.2600, 0.2650,
#         0.2700, 0.2750, 0.2800, 0.2850, 0.2900, 0.2950, 0.3000])
# epoch     0 | train loss: 0.076006487012
# epoch    10 | train loss: 0.073473900557
# epoch    20 | train loss: 0.058399148285
# epoch    30 | train loss: 0.019329410046
# epoch    40 | train loss: 0.007206616923
# epoch    50 | train loss: 0.006999406032
# epoch    60 | train loss: 0.006588730961
# epoch    70 | train loss: 0.005988860969
# epoch    80 | train loss: 0.005633926950
# epoch    90 | train loss: 0.004856385756
# epoch   100 | train loss: 0.003679843387
# epoch   110 | train loss: 0.002672433853
# epoch   120 | train loss: 0.002167758765
# epoch   130 | train loss: 0.001945500029
# epoch   140 | train loss: 0.001810862101
# epoch   150 | train loss: 0.001626382465
# epoch   160 | train loss: 0.001646105316
# epoch   170 | train loss: 0.001624664641
# epoch   180 | train loss: 0.001614121604
# epoch   190 | train loss: 0.001611499814
# epoch   200 | train loss: 0.001608838560
# epoch   210 | train loss: 0.001608016551
# epoch   220 | train loss: 0.001604702091
# epoch   230 | train loss: 0.001603236771
# epoch   240 | train loss: 0.001602283563
# epoch   250 | train loss: 0.001600200078
# epoch   260 | train loss: 0.001598650473
# epoch   270 | train loss: 0.001596867922
# epoch   280 | train loss: 0.001596633578
# epoch   290 | train loss: 0.001595064183
# epoch   300 | train loss: 0.001595229143
# epoch   310 | train loss: 0.001595728681
# epoch   320 | train loss: 0.001594640897
# epoch   330 | train loss: 0.001594648464
# epoch   340 | train loss: 0.001592350891
# epoch   350 | train loss: 0.001592947054
# epoch   360 | train loss: 0.001592211891
# epoch   370 | train loss: 0.001590964152
# epoch   380 | train loss: 0.001617731526
# epoch   390 | train loss: 0.001601598924
# epoch   400 | train loss: 0.001597572002
# epoch   410 | train loss: 0.001594149857
# epoch   420 | train loss: 0.001593954046
# epoch   430 | train loss: 0.001590861939
# epoch   440 | train loss: 0.001592096873
# epoch   450 | train loss: 0.001591029461
# epoch   460 | train loss: 0.001588823390
# epoch   470 | train loss: 0.001589209656
# epoch   480 | train loss: 0.001588745625
# epoch   490 | train loss: 0.001588626998
# epoch   500 | train loss: 0.001588092535
# epoch   510 | train loss: 0.001587631414
# epoch   520 | train loss: 0.001592385466
# epoch   530 | train loss: 0.001587793347
# epoch   540 | train loss: 0.001586496481
# epoch   550 | train loss: 0.001586017199
# epoch   560 | train loss: 0.001585645252
# epoch   570 | train loss: 0.001585830934
# epoch   580 | train loss: 0.001584456419
# epoch   590 | train loss: 0.001584412763
# epoch   600 | train loss: 0.001586756785
# epoch   610 | train loss: 0.001584120211
# epoch   620 | train loss: 0.001583998092
# epoch   630 | train loss: 0.001583809382
# epoch   640 | train loss: 0.001583641861
# epoch   650 | train loss: 0.001584729180
# epoch   660 | train loss: 0.001585427439
# epoch   670 | train loss: 0.001586702652
# epoch   680 | train loss: 0.001583177829
# epoch   690 | train loss: 0.001583546749
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-4c12c54561ce> in <module>()
#     119
#     120         loss = loss_fn(y_pd, y_gt.to(device))
# --> 121         loss.backward()
#     122         optimizer.step()
#     123
#
# /usr/local/lib/python3.6/dist-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     219                 retain_graph=retain_graph,
#     220                 create_graph=create_graph)
# --> 221         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     222
#     223     def register_hook(self, hook):
#
# /usr/local/lib/python3.6/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#     130     Variable._execution_engine.run_backward(
#     131         tensors, grad_tensors_, retain_graph, create_graph,
# --> 132         allow_unreachable=True)  # allow_unreachable flag
#     133
#     134
#
# /usr/local/lib/python3.6/dist-packages/torch/autograd/function.py in apply(self, *args)
#      87     def apply(self, *args):
#      88         # _forward_cls is defined by derived class
# ---> 89         return self._forward_cls.backward(self, *args)  # type: ignore
#      90
#      91
#
# /usr/local/lib/python3.6/dist-packages/torchdiffeq/_impl/adjoint.py in backward(ctx, grad_y)
#     137                     augmented_dynamics, tuple(aug_state),
#     138                     t[i - 1:i + 1].flip(0),
# --> 139                     rtol=adjoint_rtol, atol=adjoint_atol, method=adjoint_method, options=adjoint_options
#     140                 )
#     141                 aug_state = [a[1] for a in aug_state]  # extract just the t[i - 1] value
#
# /usr/local/lib/python3.6/dist-packages/torchdiffeq/_impl/odeint.py in odeint(func, y0, t, rtol, atol, method, options)
#      63
#      64     solver = SOLVERS[method](func=func, y0=y0, rtol=rtol, atol=atol, **options)
# ---> 65     solution = solver.integrate(t)
#      66
#      67     if shapes is not None:
#
# /usr/local/lib/python3.6/dist-packages/torchdiffeq/_impl/solvers.py in integrate(self, t)
#      85         y0 = self.y0
#      86         for t0, t1 in zip(time_grid[:-1], time_grid[1:]):
# ---> 87             dy = self._step_func(self.func, t0, t1 - t0, y0)
#      88             y1 = y0 + dy
#      89
#
# /usr/local/lib/python3.6/dist-packages/torchdiffeq/_impl/fixed_grid.py in _step_func(self, func, t, dt, y)
#      12
#      13     def _step_func(self, func, t, dt, y):
# ---> 14         return dt * func(t + self.eps, y)
#      15
#      16
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# /usr/local/lib/python3.6/dist-packages/torchdiffeq/_impl/misc.py in forward(self, t, y)
#     160
#     161     def forward(self, t, y):
# --> 162         return -self.base_func(-t, y)
#     163
#     164
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# /usr/local/lib/python3.6/dist-packages/torchdiffeq/_impl/misc.py in forward(self, t, y)
#     150
#     151     def forward(self, t, y):
# --> 152         f = self.base_func(t, _flat_to_shape(y, (), self.shapes))
#     153         return torch.cat([f_.reshape(-1) for f_ in f])
#     154
#
# /usr/local/lib/python3.6/dist-packages/torchdiffeq/_impl/adjoint.py in augmented_dynamics(t, y_aug)
#     105                     vjp_t, vjp_y, *vjp_params = torch.autograd.grad(
#     106                         func_eval, (t, y) + adjoint_params, -adj_y,
# --> 107                         allow_unused=True, retain_graph=True
#     108                     )
#     109
#
# /usr/local/lib/python3.6/dist-packages/torch/autograd/__init__.py in grad(outputs, inputs, grad_outputs, retain_graph, create_graph, only_inputs, allow_unused)
#     202     return Variable._execution_engine.run_backward(
#     203         outputs, grad_outputs_, retain_graph, create_graph,
# --> 204         inputs, allow_unused)
#     205
#     206
#
# KeyboardInterrupt:

# %% [markdown]
# **Testing Heat equation**

# %%
import torch
import torch.nn as nn

from torch_geometric.data import DataLoader

import numpy as np

import matplotlib.pyplot as plt

from pdegs.dynamics import DynamicsFunction
from pdegs.integrators import ODEAdjointIntegrator
from pdegs.models import Model3, MPNNDiff

from collections import namedtuple

import utils


# can be replaced by argparse
Config = namedtuple(
    "Config", 
    [
        "d", "hs_1", "hs_2", "method", "rtol", 
        "atol", "device", "model_path", "data_path"
    ]
)

args = Config(
    d=40,
    hs_1=60,
    hs_2=0,
    method="euler",
    rtol=1.0e-7,
    atol=1.0e-7,
    device="cuda",
    model_path="./model_gnode_heat_run_euler.pth",
    data_path="../data/subs/heat_unit_square_test_1_0p/",
)

device = torch.device(args.device)

# Create model
# Model3 
# L1_msg_net = nn.Sequential(nn.Linear(2, args.hs_1), nn.Tanh(), nn.Linear(args.hs_1, args.d))
# L1_aggr_net = nn.Sequential(nn.Linear(args.d, args.hs_1), nn.Tanh(), nn.Linear(args.hs_1, args.d))
# L2_msg_net = nn.Sequential(nn.Linear(4+args.d, args.hs_2), nn.Tanh(), nn.Linear(args.hs_2, args.d))
# L2_aggr_net = nn.Sequential(nn.Linear(args.d, args.hs_2), nn.Tanh(), nn.Linear(args.hs_2, 1))
# model = Model3(L1_msg_net, L1_aggr_net, L2_msg_net, L2_aggr_net)

# MPNN
msg_net = nn.Sequential(
    nn.Linear(4, args.hs_1), nn.Tanh(), 
    nn.Linear(args.hs_1, args.hs_1), nn.Tanh(), 
    nn.Linear(args.hs_1, args.hs_1), nn.Tanh(), 
    nn.Linear(args.hs_1, args.d)
)
aggr_net = nn.Sequential(
    nn.Linear(args.d+1, args.hs_1), nn.Tanh(), 
    nn.Linear(args.hs_1, args.hs_1), nn.Tanh(), 
    nn.Linear(args.hs_1, args.hs_1), nn.Tanh(), 
    nn.Linear(args.hs_1, 1)
)
model = MPNNDiff(msg_net, aggr_net)

F = DynamicsFunction(model).to(device)
F.load_state_dict(torch.load(args.model_path, map_location=device))

# Create integrator
adj_integr = ODEAdjointIntegrator()

# Prepare data
data = utils.read_pickle(['t', 'x', 'u'], args.data_path)
print(data['t'].shape)

dataset = utils.generate_torchgeom_dataset(data)
loader = DataLoader(dataset, batch_size=1, shuffle=False)

# Loss
loss_fn = nn.MSELoss()

# Testing
diffs_over_time = []
losses = torch.zeros(len(loader))

inds_of_sims_to_show = set([])
# Out:
# (50, 61)
# 1 / 50
# 2 / 50
# 3 / 50
# 4 / 50
# 5 / 50
# 6 / 50
# 7 / 50
# 8 / 50
# 9 / 50
# 10 / 50
# 11 / 50
# 12 / 50
# 13 / 50
# 14 / 50
# 15 / 50
# 16 / 50
# 17 / 50
# 18 / 50
# 19 / 50
# 20 / 50
# 21 / 50
# 22 / 50
# 23 / 50
# 24 / 50
# 25 / 50
# 26 / 50
# 27 / 50
# 28 / 50
# 29 / 50
# 30 / 50
# 31 / 50
# 32 / 50
# 33 / 50
# 34 / 50
# 35 / 50
# 36 / 50
# 37 / 50
# 38 / 50
# 39 / 50
# 40 / 50
# 41 / 50
# 42 / 50
# 43 / 50
# 44 / 50
# 45 / 50
# 46 / 50
# 47 / 50
# 48 / 50
# 49 / 50
# 50 / 50

# %%
# !mkdir tmp_figs_heat_1
inds_of_sims_to_show = set([1])
diffs_over_time = []

# %%
for i, dp in enumerate(loader):
    params_dict = {"edge_index": dp.edge_index.to(device), "pos": dp.pos.to(device)}
    F.update_params(params_dict)

    y0 = dp.x.to(device)
    t = dp.t.to(device)
    y_pd = adj_integr.integrate(
        F, y0, t, method=args.method, rtol=args.rtol, atol=args.atol)
    
    y_gt = dp.y.to(device)

    loss = loss_fn(y_pd, y_gt)

    losses[i] = loss.item()

    u = y_gt.cpu().detach().numpy()
    u_pd = y_pd.cpu().detach().numpy()
    u_mean = u.mean(axis=1).reshape(-1)

    # diffs = [((u[i] - u_pd[i])**2).mean() for i in range(len(u))]
    
    eps = 1.0e-6
    diffs = [np.linalg.norm(u[i].reshape(-1) - u_pd[i].reshape(-1)) / (np.linalg.norm(u[i].reshape(-1)) + eps) for i in range(len(u))]
    
    diffs_over_time.append(diffs)

    print("test case {:>5d} | test loss: {:>7.12f}".format(i, losses[i]))
    print("inds_of_sims_to_show" + str(inds_of_sims_to_show))
    if i in inds_of_sims_to_show:
        print("Plotting...")
        utils.plot_grid(dataset[i].pos.cpu().detach().numpy())
        plt.figure(0)
        utils.plot_fields(
            t=dataset[i].t,
            coords=dataset[i].pos,
            fields={
                "y_pd": y_pd.cpu().detach().numpy(),
                "y_gt": dp.y.numpy(),
            },
            save_path="./tmp_figs_heat_1/",
            delay=0.0001,
        )
        plt.show()

    # if i == 2:  # 3 for grids, 2 for time points
    #     break
# Out:
# test case     0 | test loss: 0.001422630157
# inds_of_sims_to_show{1}
# test case     1 | test loss: 0.002368568210
# inds_of_sims_to_show{1}
# Plotting...
# saving./tmp_figs_heat_1/y_gt_0.png
# saving./tmp_figs_heat_1/y_gt_1.png
# saving./tmp_figs_heat_1/y_gt_2.png
# saving./tmp_figs_heat_1/y_gt_3.png
# saving./tmp_figs_heat_1/y_gt_4.png
# saving./tmp_figs_heat_1/y_gt_5.png
# saving./tmp_figs_heat_1/y_gt_6.png
# saving./tmp_figs_heat_1/y_gt_7.png
# saving./tmp_figs_heat_1/y_gt_8.png
# saving./tmp_figs_heat_1/y_gt_9.png
# saving./tmp_figs_heat_1/y_gt_10.png
# saving./tmp_figs_heat_1/y_gt_11.png
# saving./tmp_figs_heat_1/y_gt_12.png
# saving./tmp_figs_heat_1/y_gt_13.png
# saving./tmp_figs_heat_1/y_gt_14.png
# saving./tmp_figs_heat_1/y_gt_15.png
# saving./tmp_figs_heat_1/y_gt_16.png
# saving./tmp_figs_heat_1/y_gt_17.png
# saving./tmp_figs_heat_1/y_gt_18.png
# saving./tmp_figs_heat_1/y_gt_19.png
# saving./tmp_figs_heat_1/y_gt_20.png
# saving./tmp_figs_heat_1/y_gt_21.png
# saving./tmp_figs_heat_1/y_gt_22.png
# saving./tmp_figs_heat_1/y_gt_23.png
# saving./tmp_figs_heat_1/y_gt_24.png
# saving./tmp_figs_heat_1/y_gt_25.png
# saving./tmp_figs_heat_1/y_gt_26.png
# saving./tmp_figs_heat_1/y_gt_27.png
# saving./tmp_figs_heat_1/y_gt_28.png
# saving./tmp_figs_heat_1/y_gt_29.png
# saving./tmp_figs_heat_1/y_gt_30.png
# saving./tmp_figs_heat_1/y_gt_31.png
# saving./tmp_figs_heat_1/y_gt_32.png
# saving./tmp_figs_heat_1/y_gt_33.png
# saving./tmp_figs_heat_1/y_gt_34.png
# saving./tmp_figs_heat_1/y_gt_35.png
# saving./tmp_figs_heat_1/y_gt_36.png
# saving./tmp_figs_heat_1/y_gt_37.png
# saving./tmp_figs_heat_1/y_gt_38.png
# saving./tmp_figs_heat_1/y_gt_39.png
# saving./tmp_figs_heat_1/y_gt_40.png
# saving./tmp_figs_heat_1/y_gt_41.png
# saving./tmp_figs_heat_1/y_gt_42.png
# saving./tmp_figs_heat_1/y_gt_43.png
# saving./tmp_figs_heat_1/y_gt_44.png
# saving./tmp_figs_heat_1/y_gt_45.png
# saving./tmp_figs_heat_1/y_gt_46.png
# saving./tmp_figs_heat_1/y_gt_47.png
# saving./tmp_figs_heat_1/y_gt_48.png
# saving./tmp_figs_heat_1/y_gt_49.png
# saving./tmp_figs_heat_1/y_gt_50.png
# saving./tmp_figs_heat_1/y_gt_51.png
# saving./tmp_figs_heat_1/y_gt_52.png
# saving./tmp_figs_heat_1/y_gt_53.png
# saving./tmp_figs_heat_1/y_gt_54.png
# saving./tmp_figs_heat_1/y_gt_55.png
# saving./tmp_figs_heat_1/y_gt_56.png
# saving./tmp_figs_heat_1/y_gt_57.png
# saving./tmp_figs_heat_1/y_gt_58.png
# saving./tmp_figs_heat_1/y_gt_59.png
# saving./tmp_figs_heat_1/y_gt_60.png
# test case     2 | test loss: 0.003678571666
# inds_of_sims_to_show{1}
# test case     3 | test loss: 0.001582998084
# inds_of_sims_to_show{1}
# test case     4 | test loss: 0.002540571848
# inds_of_sims_to_show{1}
# test case     5 | test loss: 0.001738418592
# inds_of_sims_to_show{1}
# test case     6 | test loss: 0.001435130253
# inds_of_sims_to_show{1}
# test case     7 | test loss: 0.001853608643
# inds_of_sims_to_show{1}
# test case     8 | test loss: 0.002334946999
# inds_of_sims_to_show{1}
# test case     9 | test loss: 0.001183322747
# inds_of_sims_to_show{1}
# test case    10 | test loss: 0.001535691670
# inds_of_sims_to_show{1}
# test case    11 | test loss: 0.001940947142
# inds_of_sims_to_show{1}
# test case    12 | test loss: 0.001007172512
# inds_of_sims_to_show{1}
# test case    13 | test loss: 0.001464257948
# inds_of_sims_to_show{1}
# test case    14 | test loss: 0.000961610873
# inds_of_sims_to_show{1}
# test case    15 | test loss: 0.002853638027
# inds_of_sims_to_show{1}
# test case    16 | test loss: 0.002811903600
# inds_of_sims_to_show{1}
# test case    17 | test loss: 0.001926447963
# inds_of_sims_to_show{1}
# test case    18 | test loss: 0.003134676954
# inds_of_sims_to_show{1}
# test case    19 | test loss: 0.001971595455
# inds_of_sims_to_show{1}
# test case    20 | test loss: 0.001064807642
# inds_of_sims_to_show{1}
# test case    21 | test loss: 0.000867005729
# inds_of_sims_to_show{1}
# test case    22 | test loss: 0.001180905732
# inds_of_sims_to_show{1}
# test case    23 | test loss: 0.002466589911
# inds_of_sims_to_show{1}
# test case    24 | test loss: 0.001192288008
# inds_of_sims_to_show{1}
# test case    25 | test loss: 0.001209199312
# inds_of_sims_to_show{1}
# test case    26 | test loss: 0.000780362228
# inds_of_sims_to_show{1}
# test case    27 | test loss: 0.001049638027
# inds_of_sims_to_show{1}
# test case    28 | test loss: 0.002150697634
# inds_of_sims_to_show{1}
# test case    29 | test loss: 0.001367991325
# inds_of_sims_to_show{1}
# test case    30 | test loss: 0.000984820887
# inds_of_sims_to_show{1}
# test case    31 | test loss: 0.001331763808
# inds_of_sims_to_show{1}
# test case    32 | test loss: 0.002696510870
# inds_of_sims_to_show{1}
# test case    33 | test loss: 0.002344801556
# inds_of_sims_to_show{1}
# test case    34 | test loss: 0.002616335638
# inds_of_sims_to_show{1}
# test case    35 | test loss: 0.001572039560
# inds_of_sims_to_show{1}
# test case    36 | test loss: 0.001952920808
# inds_of_sims_to_show{1}
# test case    37 | test loss: 0.000954477757
# inds_of_sims_to_show{1}
# test case    38 | test loss: 0.001823074534
# inds_of_sims_to_show{1}
# test case    39 | test loss: 0.001786410226
# inds_of_sims_to_show{1}
# test case    40 | test loss: 0.002805809025
# inds_of_sims_to_show{1}
# test case    41 | test loss: 0.001516634948
# inds_of_sims_to_show{1}
# test case    42 | test loss: 0.002865652321
# inds_of_sims_to_show{1}
# test case    43 | test loss: 0.000915086363
# inds_of_sims_to_show{1}
# test case    44 | test loss: 0.001471671276
# inds_of_sims_to_show{1}
# test case    45 | test loss: 0.000939687714
# inds_of_sims_to_show{1}
# test case    46 | test loss: 0.001577383373
# inds_of_sims_to_show{1}
# test case    47 | test loss: 0.001380951842
# inds_of_sims_to_show{1}
# test case    48 | test loss: 0.001816653530
# inds_of_sims_to_show{1}
# test case    49 | test loss: 0.001020362601
# inds_of_sims_to_show{1}

# %%
comp_dict = np.load("./paper_exps/comp_dict_paper_diff_step_size.npy", allow_pickle='TRUE').item()
comp_dict = {}

comp_dict_upd = {
    # 'coords_true': dataset[2].pos.numpy(), 
    # 'fields_true': dataset[2].y.numpy(),
    'coords_t_11': dataset[2].pos.numpy(),
    'fields_t_11': y_pd.cpu().detach().numpy(),
    
}
comp_dict.update(comp_dict_upd)
np.save("./paper_exps/comp_dict_paper_diff_step_size.npy", comp_dict)
print(comp_dict.keys())

print("Plotting diffs...")
plt.figure(0)
t = dataset[0].t.numpy()

for diff in diffs_over_time:
    #plt.semilogy(t, diff, alpha=0.5)
    plt.plot(t, diff, alpha=0.5)
plt.vlines(0.2, 0, 0.00002, color='gray')

plt.ylabel("Relative Error")
plt.xlabel("t (sec)")

plt.savefig("diffs_heat_eq.png")

diffs_over_time = np.array(diffs_over_time)
print("diffs_over_time.shape", diffs_over_time.shape)
print("diffs_over_time.mean", diffs_over_time.mean())

# save_to = "./plot_data/time_11tpts.npy"
# np.save(save_to, diffs_over_time)
# Out:
# dict_keys(['coords_t_11', 'fields_t_11'])
# Plotting diffs...
# diffs_over_time.shape (50, 61)
# diffs_over_time.mean 0.07930714207459595

# %%
diffs_over_time.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0d07675b7446> in <module>()
# ----> 1 diffs_over_time.shape
#
# NameError: name 'diffs_over_time' is not defined

# %%
# !touch diff_value.txt

# %%
diff_file = open("diff_value.txt")

# %%
np.savetxt('diff_file', diffs_over_time)

# %%
type(diffs_over_time)
# Out:
# numpy.ndarray

# %%
diffs_over_time
# Out:
# array([[0.        , 0.0194194 , 0.02791274, ..., 0.08682473, 0.08767194,
#         0.08847724],
#        [0.        , 0.02453216, 0.03858779, ..., 0.08848949, 0.0887732 ,
#         0.08883695],
#        [0.        , 0.02313244, 0.03413847, ..., 0.20978276, 0.21148917,
#         0.2133403 ],
#        ...,
#        [0.        , 0.02054144, 0.03039766, ..., 0.08654339, 0.08744108,
#         0.08826179],
#        [0.        , 0.02946224, 0.04813933, ..., 0.07285349, 0.07287394,
#         0.07300045],
#        [0.        , 0.02506091, 0.03848884, ..., 0.06582805, 0.06623664,
#         0.06624442]])

# %%
import seaborn as sns
import pandas as pd

# %%
df_diff = pd.DataFrame(data=diffs_over_time)

# %%
df_diff[1:2]
# Out:
#     0         1         2         3   ...        57        58        59        60
# 1  0.0  0.024532  0.038588  0.050857  ...  0.088395  0.088489  0.088773  0.088837
#
# [1 rows x 61 columns]

# %%
sns.lineplot(data= df_diff[1:2])

# %%
sns.lineplot(data=fmri, x="timepoint", y="signal", hue="event")

# %%
time_series_df = pd.DataFrame(diffs_over_time)
smooth_path = time_series_df.rolling(20).mean()
path_deviation = time_series_df.rolling(20).std()
plt.plot(smooth_path, linewidth=2)
plt.fill_between(path_deviation.index, (smooth_path-2*path_deviation)[0], (smooth_path+2*path_deviation)[0], color='b', alpha=.1)
