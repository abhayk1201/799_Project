# %%
# !git clone https://github.com/EagleW/PaperRobot.git
# Out:
# Cloning into 'PaperRobot'...
# remote: Enumerating objects: 182, done.
# remote: Total 182 (delta 0), reused 0 (delta 0), pack-reused 182
# Receiving objects: 100% (182/182), 65.31 MiB | 29.13 MiB/s, done.
# Resolving deltas: 100% (80/80), done.

# %%
ls PaperRobot/Existing\ paper\ reading
# Out:
# model/  test.py  train.py  utils/

# %%
mkdir PaperRobot/Existing\ paper\ reading/paper_reading

# %%
pwd
# Out:
# '/content'

# %%
cd PaperRobot/Existing\ paper\ reading
# Out:
# [Errno 2] No such file or directory: 'PaperRobot/Existing paper reading'
# /content/PaperRobot/Existing paper reading

# %%
ls
# Out:
# model/  paper_reading/  test.py  train.py  utils/

# %%
# !python -W ignore train.py  --batch_size 5
# Out:
# Found 23894 unique words (9146765 in total)
# tcmalloc: large alloc 1765851136 bytes == 0x102e6000 @  0x7fd4eb527001 0x7fd4e900b765 0x7fd4e906fbb0 0x7fd4e9071a4f 0x7fd4e9108048 0x50a635 0x50cd96 0x509758 0x50a48d 0x50bfb4 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64 0x509a90 0x50a48d 0x50bfb4 0x509758 0x50a48d 0x50bfb4 0x507d64 0x50ae13 0x634c82 0x634d37 0x6384ef 0x639091 0x4b0d00 0x7fd4eb122b97 0x5b250a
# finish_dump
# Finish loading train
# Finish loading valid
# Finish loading test
# Epoch 0
# Traceback (most recent call last):
#   File "train.py", line 263, in <module>
#     train(start_epoch+epoch)
#   File "train.py", line 184, in train
#     ntt[0], ntt[1], ntt[2])
#   File "/usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py", line 550, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/content/PaperRobot/Existing paper reading/model/GATA.py", line 19, in forward
#     graph = self.graph(node_features, adj)
# ...

# %%
# !python -W ignore train.py --hidden 6 --batch_size 15
# Out:
# Found 23894 unique words (9146765 in total)
# tcmalloc: large alloc 1765851136 bytes == 0x1061c000 @  0x7efd3bb28001 0x7efd3960c765 0x7efd39670bb0 0x7efd39672a4f 0x7efd39709048 0x50a635 0x50cd96 0x509758 0x50a48d 0x50bfb4 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64 0x509a90 0x50a48d 0x50bfb4 0x509758 0x50a48d 0x50bfb4 0x507d64 0x50ae13 0x634c82 0x634d37 0x6384ef 0x639091 0x4b0d00 0x7efd3b723b97 0x5b250a
# finish_dump
# Finish loading train
# Finish loading valid
# Finish loading test
# Epoch 0
# Traceback (most recent call last):
#   File "train.py", line 263, in <module>
#     train(start_epoch+epoch)
#   File "train.py", line 184, in train
#     ntt[0], ntt[1], ntt[2])
#   File "/usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py", line 550, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/content/PaperRobot/Existing paper reading/model/GATA.py", line 19, in forward
#     graph = self.graph(node_features, adj)
# ...

# %%
# !python train.py --batch_size 5
# Out:
# Found 23894 unique words (9146765 in total)
# tcmalloc: large alloc 1765851136 bytes == 0xffc0000 @  0x7f3f7517b001 0x7f3f72c5f765 0x7f3f72cc3bb0 0x7f3f72cc5a4f 0x7f3f72d5c048 0x50a635 0x50cd96 0x509758 0x50a48d 0x50bfb4 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64 0x509a90 0x50a48d 0x50bfb4 0x509758 0x50a48d 0x50bfb4 0x507d64 0x50ae13 0x634c82 0x634d37 0x6384ef 0x639091 0x4b0d00 0x7f3f74d76b97 0x5b250a
# finish_dump
# Finish loading train
# Finish loading valid
# Finish loading test
# Epoch 0
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:1569: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:1569: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# ...
